# %% [markdown]
# Hardware is the objects which is visible and Software is the internal programming which is used to run the hardware.
# ex: cpu,monitor,keyboard are hardware and programming language, Operating system are software
